# %%
tuple1 = ('damien', 'dorian')
tuple1
# Out:
# ('damien', 'dorian')

# %%
tuple2 = ('Marie', 'Luc')
tuple2
# Out:
# ('Marie', 'Luc')

# %%
dict1 = {tuple1[0] : tuple2[0], tuple1[1] : tuple2[1]}
dict1
# Out:
# {'damien': 'Marie', 'dorian': 'Luc'}

# %%
dict2 = dict1
dict2
# Out:
# {'damien': 'Marie', 'dorian': 'Luc'}

# %%
dict2['Patou'] = 'Linda'
dict2
# Out:
# {'damien': 'Marie', 'dorian': 'Luc', 'Patou': 'Linda'}
