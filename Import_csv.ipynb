# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ------------ --------------------------- 3.1/9.7 MB 29.2 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/9.7 MB 29.2 MB/s eta 0:00:01
#    -------------- ------------------------- 3.4/9.7 MB 6.4 MB/s eta 0:00:01
#    -------------- ------------------------- 3.4/9.7 MB 6.4 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.7 MB 3.7 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 3.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.7 MB 2.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.7 MB 2.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.7 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.7 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.7 MB 1.9 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\maath\Documents\Cours_EPSI_M1\Qualité de données\Dataset_Voiture_.csv")
# Out:
#    Civilité        Nom         Prénom                       E-mail  Téléphone  \
# 0        Mr     Durant           Tony                tony@yahoo.fr  202234561
# 1        M.     Dupond        Mickaël           m.dupond@gmail.com  611223344
# 2        Mr    Dubourg           Loïc            L.dubourg@live.fr   61234567
# 3        Mr     Dulong          Karim                          NaN   71234567
# 4        M.     Dugard        GÃ©rard               gege@orange.fr   21234567
# 5       Mme    Lemoine         Sophie    sophie.lemoine@hotmail.fr  609876543
# 6        M.      Morel    Jean-Claude            jc.morel@yahoo.fr  612346789
# 7       Mme      Petit   Marie-Claire       marie.claire@gmail.com  623456789
# 8        Mr     Martin           PÃul       paul.martin@outlook.fr  678901234
# 9        M.      Blanc          André        andre.blanc@gmail.com  654321098
# 10      Mme   Bertrand       Isabelle  isabelle.bertrand@gmail.com  632147890
# ...
